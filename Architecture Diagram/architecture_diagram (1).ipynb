# %%
# !pip install diagrams
from diagrams import Diagram, Cluster, Edge
from diagrams.programming.language import Python
from diagrams.custom import Custom
from diagrams.aws.storage import S3
from diagrams.aws.network import ELB
from diagrams.aws.compute import EC2
from diagrams.saas.analytics import Snowflake
from diagrams.onprem.workflow import Airflow
from diagrams.programming.framework import FastAPI
from urllib.request import urlretrieve
from diagrams.digitalocean.compute import Docker
from diagrams.onprem.database import Mongodb
from diagrams.gcp.storage import GCS
from diagrams.onprem.container import Crio
from diagrams.digitalocean.storage import Folder
from diagrams.oci.connectivity import DNS
from diagrams.elastic.beats import Filebeat
from diagrams.onprem.queue import Kafka
from diagrams.aws.general import Users
from diagrams.aws.analytics import Athena
from diagrams.azure.web import AppServiceDomains
from diagrams.gcp.compute import GCF
from diagrams.gcp.api import Endpoints
from diagrams.gcp.storage import GCS
# Out:
# Requirement already satisfied: diagrams in /usr/local/lib/python3.10/dist-packages (0.23.4)
# Requirement already satisfied: graphviz<0.21.0,>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from diagrams) (0.20.3)
# Requirement already satisfied: jinja2<4.0,>=2.10 in /usr/local/lib/python3.10/dist-packages (from diagrams) (3.1.3)
# Requirement already satisfied: typed-ast<2.0.0,>=1.5.4 in /usr/local/lib/python3.10/dist-packages (from diagrams) (1.5.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2<4.0,>=2.10->diagrams) (2.1.5)

# %%
cluster_attr = {
    "bgcolor": "white",
    "fontsize":"15"
}


graph_attr = {
    "bgcolor": "white",
    "fontsize":"15"
}

# %%
with Diagram("\n\nData Flow Web Scrapping", show=False, graph_attr=graph_attr, direction="LR") as diag:

  website_1 = DNS("The New York Times\nCBC News\nABP News\nABC News")
  bucket1 = GCS("GCP Bucket for storing Scrapped Data")
  # bucket2 = GCS("GCP Bucket for storing Cleaned Data")
  with Cluster("Airflow DAG", graph_attr=cluster_attr):
    with Cluster("Task 1"):
      web_scrapped = Python("\nScrapping\nData\nEmbed Title &\nCheck for Duplicate")
    with Cluster("Task 2"):
      data_clean = Python("\nClean Data \nand Format")
    with Cluster("Task 3"):
      summarize = Python("Summarize Text\n& Keyword Extraction")
    with Cluster("Task 4"):
      load = Python("\nLoad Data")


  openai_url = "data:image/png;base64,..."
  openai_icon = "openstack.png"
  urlretrieve(openai_url, openai_icon)
  openAI = Custom("OpenAI", openai_icon, edge_label=" ", fontsize="15", x_pos="1", y_pos="1", fontweight="bold")


  pinecone_db_url = "data:image/png;base64,..."
  pinecone_db_icon = "elastic.png"
  urlretrieve(pinecone_db_url, pinecone_db_icon)
  pinecone = Custom("Pinecone", pinecone_db_icon, edge_label=" ", x_pos="1", y_pos="1")


  snowflake = Snowflake("Data WareHouse")

website_1 >> Edge(label="Triggre Scrapping") >> web_scrapped
web_scrapped >>  Edge(label="Formatting & Cleaning") >> data_clean

web_scrapped >> Edge(label="Storing Embeddings of News Titles") >> pinecone


openAI >> Edge(label="Summarizing news") >> web_scrapped
load >> Edge(label=" ") << bucket1
summarize >> Edge(label="") << bucket1
embed_title >> summarize
summarize >> load >> Edge(label="Storng data in Final DB") >>  snowflake
web_scrapped >> Edge(label="Temporary Storage")>> bucket1 >> Edge(label="") << data_clean
# embed_title >> Edge(label="") << openAI
# summarize >> Edge(label="") << openAI
data_clean  >> Edge(label="Using NLTK") >> summarize
# load >> publish >> Edge(label="Publish Keywords") >>stream

diag
# Out:
# Warning: node '6cd1246cc38e49af8c3b2c0476b49821', graph '
#
# Data Flow Web Scrapping' size too small for label
# Warning: node '648d28c072784ba891cc3b5dc50383a5', graph '
#
# Data Flow Web Scrapping' size too small for label
# Warning: node '69fad9319fab4314a6ec82ddf21bb3c9', graph '
#
# Data Flow Web Scrapping' size too small for label
# Warning: node 'ef41632349114c138f4e63ee26fa7116', graph '
#
# Data Flow Web Scrapping' size too small for label
# Warning: node '7a0ee0bcf96c4221bfbc427520a7de7b', graph '
#
# Data Flow Web Scrapping' size too small for label
# Warning: Orthogonal edges do not currently handle edge labels. Try using xlabels.

# %%
with Diagram("\n\nData Flow for Kafka Streaming", show=False, graph_attr=graph_attr, direction="LR") as diag:
  stream = Kafka("\nData Stream")
  publish = Python("\nSubscribe")
  snowflake = Snowflake("Data WareHouse")
  python1 = Python("\nPublish")
  mongodb = Mongodb("Database")

snowflake>> python1>> stream >> Edge(label="") >>  publish >> mongodb
diag
# Out:
# Warning: node '38d2d1a35e3743af839bb1644f43e66f', graph '
#
# Data Flow for Kafka Streaming' size too small for label

# %%
with Diagram("\n\nUser Interaction", show=False, direction="LR") as diag:

  user = Users("Users", fontsize="12")

  streamlit_icon = "openstack.png"
  streamlit_url = "data:image/png;base64,..."
  urlretrieve(streamlit_url, streamlit_icon)
  streamlit_app = Custom("Streamlit \nWebapp", streamlit_icon, edge_label=" ", fontsize="12")

  fast_api_auth = FastAPI("Authenticate Users")
  fast_api_service = FastAPI("API Backend")

  mongodb = Mongodb("Database")

  # stream = Kafka("\nData Stream")

  snowflake = Snowflake("Data Warehouse")


user >> streamlit_app
streamlit_app >> Edge(label="Token") << fast_api_auth >> mongodb
streamlit_app >> Edge(label="WebSocket") << fast_api_service >> Edge(label="User Data") << mongodb
fast_api_service
fast_api_service >> Edge(lable="") << snowflake

diag
# Out:
# Warning: node 'c32b5649e0cc4220a5648eae333ea02c', graph '
#
# User Interaction' size too small for label
# Warning: node 'd4043b3e1c5c4f328ae2289d971a09d4', graph '
#
# User Interaction' size too small for label
# Warning: Orthogonal edges do not currently handle edge labels. Try using xlabels.
